# %%
import pandas as pd
import numpy
import matplotlib.pyplot as plt
import seaborn as sns
import pyarrow

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
data = [1, 2, 3, 4, 5]
print(data)
# Out:
# [1, 2, 3, 4, 5]

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %%
nbadata = pd.read_csv("data/advanced.csv")
nba_df = pd.DataFrame(nbadata)
nba_df.head()
# Out:
#    seas_id  season  player_id         player  birth_year pos   age  \
# 0    31136    2024       5025     A.J. Green         NaN  SG  24.0
# 1    31137    2024       5026    A.J. Lawson         NaN  SG  23.0
# 2    31138    2024       5027     AJ Griffin         NaN  SF  20.0
# 3    31139    2024       4219   Aaron Gordon         NaN  PF  28.0
# 4    31140    2024       4582  Aaron Holiday         NaN  PG  27.0
#
#    experience   lg   tm  ...  tov_percent  usg_percent  ows  dws   ws  ws_48  \
# 0           2  NBA  MIL  ...          5.5         15.2  0.7  0.3  1.1  0.084
# 1           2  NBA  DAL  ...          9.6         20.0  0.0  0.3  0.2  0.036
# 2           2  NBA  ATL  ...         11.3         17.3 -0.4  0.0 -0.4 -0.120
# 3          10  NBA  DEN  ...         11.2         17.8  4.5  2.6  7.1  0.148
# 4           6  NBA  HOU  ...         10.6         16.7  1.3  1.2  2.5  0.094
#
#    obpm  dbpm  bpm  vorp
# 0  -0.4  -1.7 -2.1   0.0
# 1  -3.1  -1.5 -4.6  -0.2
# ...

# %%
nba_2024 = nba_df[nba_df["season"] == 2024]
nba_2024.head()
# Out:
#    seas_id  season  player_id         player  birth_year pos   age  \
# 0    31136    2024       5025     A.J. Green         NaN  SG  24.0
# 1    31137    2024       5026    A.J. Lawson         NaN  SG  23.0
# 2    31138    2024       5027     AJ Griffin         NaN  SF  20.0
# 3    31139    2024       4219   Aaron Gordon         NaN  PF  28.0
# 4    31140    2024       4582  Aaron Holiday         NaN  PG  27.0
#
#    experience   lg   tm  ...  tov_percent  usg_percent  ows  dws   ws  ws_48  \
# 0           2  NBA  MIL  ...          5.5         15.2  0.7  0.3  1.1  0.084
# 1           2  NBA  DAL  ...          9.6         20.0  0.0  0.3  0.2  0.036
# 2           2  NBA  ATL  ...         11.3         17.3 -0.4  0.0 -0.4 -0.120
# 3          10  NBA  DEN  ...         11.2         17.8  4.5  2.6  7.1  0.148
# 4           6  NBA  HOU  ...         10.6         16.7  1.3  1.2  2.5  0.094
#
#    obpm  dbpm  bpm  vorp
# 0  -0.4  -1.7 -2.1   0.0
# 1  -3.1  -1.5 -4.6  -0.2
# ...

# %%
sg_df = nba_df[nba_df["pos"] == "SG"]
sg_df.head()
# Out:
#     seas_id  season  player_id         player  birth_year pos   age  \
# 0     31136    2024       5025     A.J. Green         NaN  SG  24.0
# 1     31137    2024       5026    A.J. Lawson         NaN  SG  23.0
# 6     31142    2024       4900  Aaron Wiggins         NaN  SG  25.0
# 7     31143    2024       5109   Adam Flagler         NaN  SG  24.0
# 11    31147    2024       3982     Alec Burks         NaN  SG  32.0
#
#     experience   lg   tm  ...  tov_percent  usg_percent  ows  dws   ws  ws_48  \
# 0            2  NBA  MIL  ...          5.5         15.2  0.7  0.3  1.1  0.084
# 1            2  NBA  DAL  ...          9.6         20.0  0.0  0.3  0.2  0.036
# 6            3  NBA  OKC  ...         12.1         16.4  2.1  1.6  3.7  0.144
# 7            1  NBA  OKC  ...          0.0         21.7  0.0  0.0  0.0 -0.159
# 11          13  NBA  TOT  ...          7.0         24.4  0.7  0.7  1.4  0.054
#
#     obpm  dbpm   bpm  vorp
# 0   -0.4  -1.7  -2.1   0.0
# 1   -3.1  -1.5  -4.6  -0.2
# ...
